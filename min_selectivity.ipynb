# %%
from algos.MinSel import min_selectivity


algo_energy = []
solution_energy = []
pg_energy = []

solution_cost = []
pg_cost = []

solution_latency = []
pg_latency = []


query_names = ['3b','1a','32a','8a','7a','25a','19a','22a','24a','28a','29b']


for query in query_names:
    print("----------------------------------------------------------")
    print(query)
    with open('/home/said/Desktop/projects/job_algos/JOB-queries/'+ str(query) + '.sql', 'r') as file:

        query = file.read()

        solution , cost = min_selectivity(query)
        solution_cost.append(cost)

    print(solution_cost)
# Out:
# ----------------------------------------------------------
# 3b
# 4 - is recording:  1
# query:  SELECT COUNT(*) FROM keyword AS k WHERE k.keyword LIKE '%sequel%'
# query:  SELECT COUNT(*) FROM movie_info AS mi WHERE mi.info IN ('Bulgaria')
# query:  SELECT COUNT(*) FROM title AS t WHERE t.production_year > 2010
# File 3b.sql created in directory solutions/ms
# startTime:  2023-04-11 13:26:39:579826  - endTime:  2023-04-11 13:26:41:113343
# stop recording :  2023-04-11 13:26:43.115487
# 7 - is recording:  0
# avg_power :  120.10833333333333
# Time(s):  1.533517  - AVG Power(w):  120.10833333333333  - Energy(J):  184.18817100833334
# 4 - is recording:  1
# startTime:  2023-04-11 13:26:46:011  - endTime:  2023-04-11 13:26:46:274191
# stop recording :  2023-04-11 13:26:48.275735
# 7 - is recording:  0
# avg_power :  115.416
# Time(s):  0.263191  - AVG Power(w):  115.416  - Energy(J):  30.376452456
# 4 - is recording:  1
# startTime:  2023-04-11 13:26:51:029  - endTime:  2023-04-11 13:26:51:240947
# stop recording :  2023-04-11 13:26:53.243121
# 7 - is recording:  0
# avg_power :  120.901
# Time(s):  0.211947  - AVG Power(w):  120.901  - Energy(J):  25.624604246999997
# 4 - is recording:  1
# startTime:  2023-04-11 13:26:56:131  - endTime:  2023-04-11 13:26:56:358515
# stop recording :  2023-04-11 13:26:58.359742
# 7 - is recording:  0
# avg_power :  123.205
# Time(s):  0.227515  - AVG Power(w):  123.205  - Energy(J):  28.030985575
# solution_cost :  [34228.3]
# solution_latency :  [208.748]
# ---------------------------------------
# algo_energy : [184.18817100833334]
# pg_plan_energy : [28.030985575]
# ---------------------------------------
# solution_energy [25.624604246999997]
# pg_exec_energy [30.376452456]
# ----------------------------------------------------------
# 1a
# 4 - is recording:  1
# ddddd {'or': [{'like': ['mc.note', {'literal': '%(co-production)%'}]}, {'like': ['mc.note', {'literal': '%(presents)%'}]}]}
# query:  SELECT COUNT(*) FROM company_type AS ct WHERE ct.kind = 'production companies'
# query:  SELECT COUNT(*) FROM info_type AS it WHERE it.info = 'top 250 rank'
# query:  SELECT COUNT(*) FROM movie_companies AS mc WHERE mc.note NOT LIKE '%(as Metro-Goldwyn-Mayer Pictures)%' AND (mc.note LIKE '%(co-production)%' OR mc.note LIKE '%(presents)%')
# File 1a.sql created in directory solutions/ms
# startTime:  2023-04-11 13:27:01:433066  - endTime:  2023-04-11 13:27:02:419660
# stop recording :  2023-04-11 13:27:04.421757
# 7 - is recording:  0
# avg_power :  115.9725
# Time(s):  0.986594  - AVG Power(w):  115.9725  - Energy(J):  114.41777266499999
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:07:318  - endTime:  2023-04-11 13:27:07:475669
# stop recording :  2023-04-11 13:27:09.477834
# 7 - is recording:  0
# avg_power :  117.447
# Time(s):  0.157669  - AVG Power(w):  117.447  - Energy(J):  18.517751043
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:12:367  - endTime:  2023-04-11 13:27:12:527584
# stop recording :  2023-04-11 13:27:14.529207
# 7 - is recording:  0
# avg_power :  118.535
# Time(s):  0.160584  - AVG Power(w):  118.535  - Energy(J):  19.03482444
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:17:415  - endTime:  2023-04-11 13:27:17:576689
# stop recording :  2023-04-11 13:27:19.578783
# 7 - is recording:  0
# avg_power :  118.426
# Time(s):  0.161689  - AVG Power(w):  118.426  - Energy(J):  19.148181514
# solution_cost :  [34228.3, 19966.0]
# solution_latency :  [208.748, 156.857]
# ---------------------------------------
# algo_energy : [184.18817100833334, 114.41777266499999]
# pg_plan_energy : [28.030985575, 19.148181514]
# ---------------------------------------
# solution_energy [25.624604246999997, 19.03482444]
# pg_exec_energy [30.376452456, 18.517751043]
# ----------------------------------------------------------
# 32a
# 4 - is recording:  1
# query:  SELECT COUNT(*) FROM keyword AS k WHERE k.keyword = '10,000-mile-club'
# File 32a.sql created in directory solutions/ms
# startTime:  2023-04-11 13:27:22:687924  - endTime:  2023-04-11 13:27:22:778917
# stop recording :  2023-04-11 13:27:24.779767
# 7 - is recording:  0
# avg_power :  116.049
# Time(s):  0.090993  - AVG Power(w):  116.049  - Energy(J):  10.559646657000002
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:27:671  - endTime:  2023-04-11 13:27:27:705554
# stop recording :  2023-04-11 13:27:29.707428
# 7 - is recording:  0
# avg_power :  117.989
# Time(s):  0.034554  - AVG Power(w):  117.989  - Energy(J):  4.076991906
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:32:514  - endTime:  2023-04-11 13:27:32:545566
# stop recording :  2023-04-11 13:27:34.547731
# 7 - is recording:  0
# avg_power :  118.141
# Time(s):  0.031566  - AVG Power(w):  118.141  - Energy(J):  3.7292388059999997
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:37:438  - endTime:  2023-04-11 13:27:37:470902
# stop recording :  2023-04-11 13:27:39.471737
# 7 - is recording:  0
# avg_power :  117.541
# Time(s):  0.032902  - AVG Power(w):  117.541  - Energy(J):  3.867333982
# solution_cost :  [34228.3, 19966.0, 5479.82]
# solution_latency :  [208.748, 156.857, 20.121]
# ---------------------------------------
# algo_energy : [184.18817100833334, 114.41777266499999, 10.559646657000002]
# pg_plan_energy : [28.030985575, 19.148181514, 3.867333982]
# ---------------------------------------
# solution_energy [25.624604246999997, 19.03482444, 3.7292388059999997]
# pg_exec_energy [30.376452456, 18.517751043, 4.076991906]
# ----------------------------------------------------------
# 8a
# 4 - is recording:  1
# query:  SELECT COUNT(*) FROM cast_info AS ci WHERE ci.note = '(voice: English version)'
# query:  SELECT COUNT(*) FROM company_name AS cn WHERE cn.country_code = '[jp]'
# query:  SELECT COUNT(*) FROM movie_companies AS mc WHERE mc.note LIKE '%(Japan)%' AND mc.note NOT LIKE '%(USA)%'
# query:  SELECT COUNT(*) FROM name AS n1 WHERE n1.name LIKE '%Yo%' AND n1.name NOT LIKE '%Yu%'
# query:  SELECT COUNT(*) FROM role_type AS rt WHERE rt.role = 'actress'
# File 8a.sql created in directory solutions/ms
# startTime:  2023-04-11 13:27:42:387206  - endTime:  2023-04-11 13:27:43:630751
# stop recording :  2023-04-11 13:27:45.631748
# 7 - is recording:  0
# avg_power :  115.224
# Time(s):  1.243545  - AVG Power(w):  115.224  - Energy(J):  143.28622908
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:48:547  - endTime:  2023-04-11 13:27:48:871735
# stop recording :  2023-04-11 13:27:50.873919
# 7 - is recording:  0
# avg_power :  118.261
# Time(s):  0.324735  - AVG Power(w):  118.261  - Energy(J):  38.403485835
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:53:761  - endTime:  2023-04-11 13:27:54:066583
# stop recording :  2023-04-11 13:27:56.067754
# 7 - is recording:  0
# avg_power :  117.1975
# Time(s):  0.305583  - AVG Power(w):  117.1975  - Energy(J):  35.8135636425
# 4 - is recording:  1
# startTime:  2023-04-11 13:27:58:961  - endTime:  2023-04-11 13:27:59:260709
# stop recording :  2023-04-11 13:28:01.260993
# 7 - is recording:  0
# avg_power :  112.729
# Time(s):  0.299709  - AVG Power(w):  112.729  - Energy(J):  33.785895861
# solution_cost :  [34228.3, 19966.0, 5479.82, 62253.63]
# solution_latency :  [208.748, 156.857, 20.121, 288.491]
# ---------------------------------------
# algo_energy : [184.18817100833334, 114.41777266499999, 10.559646657000002, 143.28622908]
# pg_plan_energy : [28.030985575, 19.148181514, 3.867333982, 33.785895861]
# ---------------------------------------
# solution_energy [25.624604246999997, 19.03482444, 3.7292388059999997, 35.8135636425]
# pg_exec_energy [30.376452456, 18.517751043, 4.076991906, 38.403485835]
# ----------------------------------------------------------
# 7a
# 4 - is recording:  1
# ddddd {'or': [{'eq': ['n.gender', {'literal': 'm'}]}, {'and': [{'eq': ['n.gender', {'literal': 'f'}]}, {'like': ['n.name', {'literal': 'B%'}]}]}]}
# query:  SELECT COUNT(*) FROM aka_name AS an WHERE an.name LIKE '%a%'
# query:  SELECT COUNT(*) FROM info_type AS it WHERE it.info = 'mini biography'
# query:  SELECT COUNT(*) FROM link_type AS lt WHERE lt.link = 'features'
# query:  SELECT COUNT(*) FROM name AS n WHERE n.name_pcode_cf BETWEEN 'A' AND 'F' AND (n.gender = 'm' OR n.gender = 'f' AND n.name LIKE 'B%')
# query:  SELECT COUNT(*) FROM person_info AS pi WHERE pi.note = 'Volker Boehm'
# query:  SELECT COUNT(*) FROM title AS t WHERE t.production_year BETWEEN 1980 AND 1995
# File 7a.sql created in directory solutions/ms
# startTime:  2023-04-11 13:28:04:393286  - endTime:  2023-04-11 13:28:05:913718
# stop recording :  2023-04-11 13:28:07.915736
# 7 - is recording:  0
# avg_power :  118.416
# Time(s):  1.520432  - AVG Power(w):  118.416  - Energy(J):  180.043475712
