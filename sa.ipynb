# %%
import csv
from algos.helper_functions import create_file, get_query_latency
from energy.energy_functions import *
from algos.SA import simulated_annealing
solutions = []
algo_energy = []
solution_energy = []
pg_energy = []

solution_cost = []
pg_cost = []

solution_latency = []
pg_latency = []

algo_metadata={}

# Set the path to the directory containing the files
directory_path = "JOB-queries"


# Loop over all the files in the directory
for filename in os.listdir(directory_path):

    # Check if the file is a file and not a directory
    if os.path.isfile(os.path.join(directory_path, filename)) :  # and filename in elements:
        # Open the file for reading
        with open(os.path.join(directory_path, filename), 'r', encoding="utf8") as file:
            # Read the contents of the file
            query = file.read()

            #apply the algorithm
            solution, cost = simulated_annealing(query, 10, 8, 0.5)



        print("solution_cost : ", solution_cost)
# Out:
# ------------------------------------------------
# current join order:  [{'value': 'link_type', 'name': 'lt'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't1'}, {'value': 'title', 'name': 't2'}]
# current join order cost:  5478.94
# ------------------------------------------------
# best cost 5478.94
# ------------------------------------------------
# current join order:  [{'value': 'link_type', 'name': 'lt'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't1'}, {'value': 'title', 'name': 't2'}]
# current join order cost:  5478.94
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't2'}, {'value': 'title', 'name': 't1'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'link_type', 'name': 'lt'}]
# current join order cost:  5269.85
# ------------------------------------------------
# best cost 5269.85
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't2'}, {'value': 'title', 'name': 't1'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}]
# current join order cost:  5269.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't2'}, {'value': 'title', 'name': 't1'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'link_type', 'name': 'lt'}]
# current join order cost:  5269.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't2'}, {'value': 'title', 'name': 't1'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'link_type', 'name': 'lt'}]
# current join order cost:  5269.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'link_type', 'name': 'lt'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't1'}, {'value': 'title', 'name': 't2'}]
# current join order cost:  5478.92
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't2'}, {'value': 'title', 'name': 't1'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}]
# current join order cost:  5269.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't2'}, {'value': 'title', 'name': 't1'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'link_type', 'name': 'lt'}]
# current join order cost:  5269.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't1'}, {'value': 'title', 'name': 't2'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'link_type', 'name': 'lt'}]
# current join order cost:  5269.85
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  8372.13
# ------------------------------------------------
# best cost 8372.13
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'name', 'name': 'n'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'name', 'name': 'n'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}]
# current join order cost:  8372.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'name', 'name': 'n'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}]
# current join order cost:  8372.23
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5574.87
# ------------------------------------------------
# best cost 5574.87
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5574.87
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'company_name', 'name': 'cn'}]
# current join order cost:  5473.44
# ------------------------------------------------
# best cost 5473.44
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}]
# current join order cost:  5317.22
# ------------------------------------------------
# best cost 5317.22
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}]
# current join order cost:  5472.49
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  5283.88
# ------------------------------------------------
# best cost 5283.88
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}]
# current join order cost:  5317.22
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'aka_name', 'name': 'an'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  5281.4
# ------------------------------------------------
# best cost 5281.4
# ------------------------------------------------
# current join order:  [{'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'aka_name', 'name': 'an'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  5290.6
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  5283.88
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5408.33
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5406.31
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'keyword', 'name': 'k'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5420.89
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5406.31
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'name', 'name': 'n'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5416.67
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5403.67
# ------------------------------------------------
# best cost 5403.67
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5415.88
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5410.04
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5402.01
# ------------------------------------------------
# best cost 5402.01
# ------------------------------------------------
# current join order:  [{'value': 'aka_name', 'name': 'an'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it3'}, {'value': 'keyword', 'name': 'k'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'person_info', 'name': 'pi'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5408.33
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}]
# current join order cost:  34922.51
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  34920.85
# ------------------------------------------------
# best cost 34920.85
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}]
# current join order cost:  34922.51
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  34920.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_info', 'name': 'mi'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}]
# current join order cost:  34920.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  34920.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  34920.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  34920.85
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  34922.51
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  34922.51
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'complete_cast', 'name': 'cc'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  10632.16
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'complete_cast', 'name': 'cc'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  10632.16
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  10632.16
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'title', 'name': 't'}]
# current join order cost:  10632.16
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'info_type', 'name': 'it1'}]
# current join order cost:  10627.79
# ------------------------------------------------
# best cost 10627.79
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it1'}]
# current join order cost:  10627.79
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  10627.79
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  10627.79
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  10627.79
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  10632.19
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'cast_info', 'name': 'ci'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'name', 'name': 'n'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}, {'value': 'name', 'name': 'n'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_keyword', 'name': 'mk'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}, {'value': 'name', 'name': 'n'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'name', 'name': 'n'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  23565.91
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'name', 'name': 'n'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'keyword', 'name': 'k'}, {'value': 'title', 'name': 't'}, {'value': 'movie_keyword', 'name': 'mk'}]
# current join order cost:  23565.91
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11266.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'keyword', 'name': 'k'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11266.17
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11266.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'keyword', 'name': 'k'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11266.14
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11266.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11266.13
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11265.66
# ------------------------------------------------
# best cost 11265.66
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11265.66
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11264.96
# ------------------------------------------------
# best cost 11264.96
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  11264.96
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'char_name', 'name': 'chn'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'char_name', 'name': 'chn'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'char_name', 'name': 'chn'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}]
# current join order cost:  62108.07
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'title', 'name': 't'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'cast_info', 'name': 'ci'}]
# current join order cost:  62108.07
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  62173.75
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}]
# current join order cost:  62173.75
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62141.33
# ------------------------------------------------
# best cost 62141.33
# ------------------------------------------------
# current join order:  [{'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62141.33
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}]
# current join order cost:  62173.75
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62141.33
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'title', 'name': 't'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62141.33
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62174.71
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'role_type', 'name': 'rt'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'title', 'name': 't'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  62141.33
# ------------------------------------------------
# ...
# current join order cost:  68027.04
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'name', 'name': 'n'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'aka_name', 'name': 'an'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  68027.04
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'name', 'name': 'n'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'aka_name', 'name': 'an'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  68027.04
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'aka_name', 'name': 'an'}, {'value': 'char_name', 'name': 'chn'}, {'value': 'name', 'name': 'n'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'title', 'name': 't'}]
# current join order cost:  68445.31
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'name', 'name': 'n'}, {'value': 'title', 'name': 't'}, {'value': 'role_type', 'name': 'rt'}, {'value': 'cast_info', 'name': 'ci'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'aka_name', 'name': 'an'}, {'value': 'char_name', 'name': 'chn'}]
# current join order cost:  68006.81
# ------------------------------------------------
# best cost 68006.81
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'keyword', 'name': 'k'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_name', 'name': 'cn'}, {'value': 'keyword', 'name': 'k'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'keyword', 'name': 'k'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'title', 'name': 't'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  13241.43
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'info_type', 'name': 'it2'}, {'value': 'info_type', 'name': 'it1'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'kind_type', 'name': 'kt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_info_idx', 'name': 'mi_idx'}, {'value': 'keyword', 'name': 'k'}]
# current join order cost:  13241.43
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'title', 'name': 't'}]
# current join order cost:  77163.47
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'info_type', 'name': 'it'}, {'value': 'title', 'name': 't'}]
# current join order cost:  77163.47
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}]
# current join order cost:  77161.61
# ------------------------------------------------
# best cost 77161.61
# ------------------------------------------------
# current join order:  [{'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'info_type', 'name': 'it'}, {'value': 'title', 'name': 't'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  77163.47
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  77161.61
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it'}, {'value': 'title', 'name': 't'}]
# current join order cost:  77163.47
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it'}, {'value': 'title', 'name': 't'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  77161.61
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'company_type', 'name': 'ct'}, {'value': 'title', 'name': 't'}, {'value': 'info_type', 'name': 'it'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  77161.61
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'info_type', 'name': 'it'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'movie_info', 'name': 'mi'}]
# current join order cost:  77161.61
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'title', 'name': 't'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'info_type', 'name': 'it'}, {'value': 'company_type', 'name': 'ct'}]
# current join order cost:  77161.61
# ------------------------------------------------
# solution_cost :  []
# ------------------------------------------------
# current join order:  [{'value': 'complete_cast', 'name': 'cc'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'keyword', 'name': 'k'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5308.5
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'complete_cast', 'name': 'cc'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'keyword', 'name': 'k'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5308.5
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'keyword', 'name': 'k'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'title', 'name': 't'}]
# current join order cost:  5308.5
# ------------------------------------------------
# ------------------------------------------------
# current join order:  [{'value': 'complete_cast', 'name': 'cc'}, {'value': 'company_name', 'name': 'cn'}, {'value': 'company_type', 'name': 'ct'}, {'value': 'movie_companies', 'name': 'mc'}, {'value': 'link_type', 'name': 'lt'}, {'value': 'title', 'name': 't'}, {'value': 'movie_link', 'name': 'ml'}, {'value': 'movie_keyword', 'name': 'mk'}, {'value': 'comp_cast_type', 'name': 'cct1'}, {'value': 'comp_cast_type', 'name': 'cct2'}, {'value': 'movie_info', 'name': 'mi'}, {'value': 'keyword', 'name': 'k'}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_29589/3331734193.py in <module>
#      31
#      32             #apply the algorithm
# ---> 33             solution, cost = simulated_annealing(query, 10, 8, 0.5)
#      34
#      35
#
# ~/Desktop/projects/join_order_trad_algorithms/algos/SA.py in simulated_annealing(query, num_iterations, initial_temperature, cooling_rate)
#      28         print("current join order: ",neighbor)
#      29         # Calculate the cost of the neighbor
# ---> 30         neighbor_cost = get_join_order_cost(parsed_query, neighbor)
#      31         print("current join order cost: ",neighbor_cost)
#      32
#
# ~/Desktop/projects/join_order_trad_algorithms/algos/helper_functions.py in get_join_order_cost(parsed_query, join_order)
#     144     modified_query = get_modified_query(parsed_query, join_order)
#     145
# --> 146     conn, cursor = connect_bdd("imdbload")
#     147     cursor.execute("SET join_collapse_limit = 1;")
#     148     cursor.execute("explain (format json) " + modified_query)
#
# ~/Desktop/projects/join_order_trad_algorithms/algos/helper_functions.py in connect_bdd(name)
#      99     conn = psycopg2.connect(host="localhost",
#     100                             user="postgres", password="postgres",
# --> 101                             database=name)
#     102     cursor = conn.cursor()
#     103     return [conn, cursor]
#
# ~/anaconda3/envs/jos/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# KeyboardInterrupt:
